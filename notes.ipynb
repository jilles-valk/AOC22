# %%
f = open("01_input.txt")
f.readlines()
# Out:
# ['9686\n',
#  '10178\n',
#  '3375\n',
#  '9638\n',
#  '6318\n',
#  '4978\n',
#  '5988\n',
#  '6712\n',
#  '\n',
#  '10422\n',
#  '3062\n',
#  '2753\n',
#  '3695\n',
#  '1722\n',
#  '8110\n',
#  '6568\n',
#  '7124\n',
#  '\n',
#  '3162\n',
#  '6117\n',
#  '2560\n',
#  '8788\n',
#  '2413\n',
#  '3719\n',
#  '1052\n',
#  '1349\n',
#  '4780\n',
#  '5178\n',
#  '\n',
#  '24919\n',
#  '15983\n',
#  '18045\n',
#  '\n',
#  '24872\n',
#  '35761\n',
#  '\n',
#  '20914\n',
#  '\n',
#  '4701\n',
#  '7592\n',
#  '1014\n',
#  '12219\n',
#  '3794\n',
#  '6893\n',
#  '\n',
#  '6471\n',
#  '5100\n',
#  '4297\n',
#  '8538\n',
#  '3923\n',
#  '8135\n',
#  '2015\n',
#  '2255\n',
#  '\n',
#  '1631\n',
#  '8016\n',
#  '4371\n',
#  '5797\n',
#  '5252\n',
#  '1487\n',
#  '8289\n',
#  '8886\n',
#  '1149\n',
#  '\n',
#  '8082\n',
#  '8747\n',
#  '4577\n',
#  '3624\n',
#  '4481\n',
#  '7947\n',
#  '2790\n',
#  '9217\n',
#  '4729\n',
#  '\n',
#  '4069\n',
#  '1728\n',
#  '4093\n',
#  '2978\n',
#  '6582\n',
# ...

# %%
line = "vJrwpWtwJgWrhcsFMMfFFhFp"
l = len(line)
compartment_a = line[0:int(l/2)]
compartment_b = line[int(l/2):]
print(compartment_a)
print(compartment_b)
# Out:
# vJrwpWtwJgWr
# hcsFMMfFFhFp

# %%
ord("A") - 64
# Out:
# 1

# %%
-64+27
# Out:
# -37

# %%
1 - 0 = 1
2 - 1 = 1
0 - 2 % 3= 1

# %%
3%2
# Out:
# 1
